# %% [markdown]
# # Phase 2 - Week 1 - Day 2 AM - Training Artificial Neural Network: Part 1

# %% [markdown]
# **The purpose of this notebook is to demonstrate the effect of selecting the sigmoid activation function so that a vanishing gradient occurs.**
#
# Then an experiment will be carried out if the activation function is changed to ReLU.

# %% [markdown]
# The vanishing gradient problem occurs when gradients (slopes) during backpropagation **become extremely small** as they are propagated backward through the layers of a deep neural network.
#
# When gradients are very small, the updates to the network's parameters become negligible, leading to slow or stalled training.
#
# The vanishing gradient problem is typically caused by activation functions like the sigmoid or hyperbolic tangent (tanh) functions, which squash input values into a small range (e.g., between 0 and 1 or -1 and 1). When these functions are repeatedly applied in deep networks, gradients can shrink to near-zero values.
#
# As a result, deep layers of the network fail to learn meaningful representations from the data, and the network may not converge to a good solution.
#
# **The model weights can become 0 in the training phase.**

# %% [markdown]
# # A. Import Libraries & Data Loading

# %%
# Import Libraries
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

from tensorflow.keras import Sequential
from tensorflow.keras.initializers import RandomNormal, HeNormal
from tensorflow.keras.layers import Input, Dense
# Out:
# WARNING:tensorflow:From C:\Users\Gilbert KH\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# In this experiment, we will create an artificial dataset regarding Binary Classification

# %%
# Make Dataset

X, y = make_circles(n_samples=1000, factor=0.5, noise=0.1)

plt.figure(figsize=(8,6))
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
# Data Splitting

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)
print('Train size : ', X_train.shape)
print('Test size  : ', X_test.shape)
# Out:
# Train size :  (850, 2)
# Test size  :  (150, 2)

# %% [markdown]
# # B. Model with Sigmoid

# %% [markdown]
# For first model, we will create an ANN model with configuration :
#
# * 2 input neuron (based on the number of features)
# * 5 hidden layer
# * Each hidden layer will contains 5 hidden neurons
# * Weight Initialization : Random Normal
# * Loss function : Binary Cross Entropy
# * Optimizer : Adam

# %%
# Create ANN Model

seed = 20
tf.keras.backend.clear_session()
np.random.seed(seed)
tf.random.set_seed(seed)

initializer = RandomNormal(mean=0, stddev=1, seed=seed)
loss_function = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.Adam()

model_sigmoid = Sequential([
    Input(shape=(2,), name='input-layer'),
    Dense(5, activation='sigmoid', kernel_initializer=initializer, name='hidden-layer-1'),
    Dense(5, activation='sigmoid', kernel_initializer=initializer, name='hidden-layer-2'),
    Dense(5, activation='sigmoid', kernel_initializer=initializer, name='hidden-layer-3'),
    Dense(1, activation="sigmoid", kernel_initializer=initializer, name='output-layer')
])

# Compile
model_sigmoid.compile(loss=loss_function, optimizer=optimizer, metrics=['accuracy'])
model_sigmoid.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Gilbert KH\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden-layer-1 (Dense)      (None, 5)                 15
#
#  hidden-layer-2 (Dense)      (None, 5)                 30
#
#  hidden-layer-3 (Dense)      (None, 5)                 30
#
#  output-layer (Dense)        (None, 1)                 6
#
# =================================================================
# Total params: 81 (324.00 Byte)
# Trainable params: 81 (324.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the ANN Model

model_sigmoid.fit(X_train, y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\Gilbert KH\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Gilbert KH\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 27/27 [==============================] - 2s 2ms/step - loss: 0.7003 - accuracy: 0.4988
# Epoch 2/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6965 - accuracy: 0.4988
# Epoch 3/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6948 - accuracy: 0.4894
# Epoch 4/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6944 - accuracy: 0.4047
# Epoch 5/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6937 - accuracy: 0.4353
# Epoch 6/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6935 - accuracy: 0.4741
# Epoch 7/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6935 - accuracy: 0.4941
# Epoch 8/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6936 - accuracy: 0.4624
# Epoch 9/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.5024
# Epoch 10/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.5118
# Epoch 11/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5282
# Epoch 12/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6930 - accuracy: 0.5459
# Epoch 13/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6930 - accuracy: 0.5424
# Epoch 14/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6930 - accuracy: 0.5306
# Epoch 15/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5118
# Epoch 16/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.5129
# Epoch 17/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.5247
# Epoch 18/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.5835
# Epoch 19/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.5353
# Epoch 20/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6926 - accuracy: 0.5271
# Epoch 21/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6927 - accuracy: 0.5741
# Epoch 22/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6924 - accuracy: 0.5482
# Epoch 23/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6924 - accuracy: 0.5212
# Epoch 24/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6924 - accuracy: 0.5129
# Epoch 25/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6922 - accuracy: 0.5271
# Epoch 26/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6922 - accuracy: 0.5494
# Epoch 27/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6921 - accuracy: 0.5400
# Epoch 28/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.5682
# Epoch 29/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6920 - accuracy: 0.5906
# Epoch 30/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6920 - accuracy: 0.5388
# Epoch 31/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6919 - accuracy: 0.5459
# Epoch 32/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6919 - accuracy: 0.5388
# Epoch 33/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6916 - accuracy: 0.5365
# Epoch 34/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6917 - accuracy: 0.5612
# Epoch 35/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6915 - accuracy: 0.5506
# Epoch 36/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6915 - accuracy: 0.5306
# Epoch 37/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6913 - accuracy: 0.5412
# Epoch 38/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6912 - accuracy: 0.5459
# Epoch 39/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6911 - accuracy: 0.5706
# Epoch 40/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6910 - accuracy: 0.5482
# Epoch 41/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6908 - accuracy: 0.5447
# Epoch 42/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6909 - accuracy: 0.5718
# Epoch 43/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6907 - accuracy: 0.5600
# Epoch 44/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5518
# Epoch 45/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6904 - accuracy: 0.5353
# Epoch 46/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6903 - accuracy: 0.5424
# Epoch 47/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6902 - accuracy: 0.5588
# Epoch 48/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6902 - accuracy: 0.5459
# Epoch 49/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6899 - accuracy: 0.5447
# Epoch 50/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6897 - accuracy: 0.5459
# Epoch 51/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6896 - accuracy: 0.5447
# Epoch 52/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6894 - accuracy: 0.5482
# Epoch 53/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6893 - accuracy: 0.5612
# Epoch 54/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6890 - accuracy: 0.5706
# Epoch 55/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6892 - accuracy: 0.5494
# Epoch 56/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6891 - accuracy: 0.5824
# Epoch 57/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6886 - accuracy: 0.5529
# Epoch 58/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6884 - accuracy: 0.5365
# Epoch 59/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6882 - accuracy: 0.5424
# Epoch 60/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6880 - accuracy: 0.5553
# Epoch 61/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6877 - accuracy: 0.5788
# Epoch 62/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6876 - accuracy: 0.5647
# Epoch 63/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6872 - accuracy: 0.5529
# Epoch 64/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6869 - accuracy: 0.5588
# Epoch 65/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6867 - accuracy: 0.5518
# Epoch 66/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.5671
# Epoch 67/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6861 - accuracy: 0.5741
# Epoch 68/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6860 - accuracy: 0.5635
# Epoch 69/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.5635
# Epoch 70/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6853 - accuracy: 0.5706
# Epoch 71/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.5600
# Epoch 72/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.5647
# Epoch 73/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6843 - accuracy: 0.5624
# Epoch 74/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6839 - accuracy: 0.5612
# Epoch 75/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6838 - accuracy: 0.5765
# Epoch 76/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6831 - accuracy: 0.5694
# Epoch 77/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6829 - accuracy: 0.5565
# Epoch 78/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6824 - accuracy: 0.5635
# Epoch 79/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6820 - accuracy: 0.5659
# Epoch 80/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6816 - accuracy: 0.5635
# Epoch 81/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6812 - accuracy: 0.5682
# Epoch 82/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6807 - accuracy: 0.5635
# Epoch 83/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6802 - accuracy: 0.5788
# Epoch 84/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6797 - accuracy: 0.5776
# Epoch 85/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6794 - accuracy: 0.5694
# Epoch 86/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6788 - accuracy: 0.5812
# Epoch 87/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6783 - accuracy: 0.5812
# Epoch 88/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6779 - accuracy: 0.5824
# Epoch 89/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6773 - accuracy: 0.5765
# Epoch 90/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6768 - accuracy: 0.5788
# Epoch 91/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6762 - accuracy: 0.5741
# Epoch 92/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6756 - accuracy: 0.5765
# Epoch 93/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6755 - accuracy: 0.5753
# Epoch 94/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6746 - accuracy: 0.5871
# Epoch 95/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6742 - accuracy: 0.5812
# Epoch 96/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6735 - accuracy: 0.5871
# Epoch 97/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6728 - accuracy: 0.5859
# Epoch 98/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6722 - accuracy: 0.5847
# Epoch 99/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6716 - accuracy: 0.5871
# Epoch 100/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6717 - accuracy: 0.5882

# %%
# Predict test-set

model_sigmoid.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6833 - accuracy: 0.5533
# [0.6832940578460693, 0.5533333420753479]

# %% [markdown]
# Unfortunately, the performance of the model using the sigmoid is too low when tested with a test-set. The accuracy value only reaches 58 %.

# %% [markdown]
# # C. Model with ReLU

# %% [markdown]
# Let's improve our model by changing :
#
# * The activation function to ReLU
# * Weight initialization to HeNormal (HeNormal is more suitable for use by ReLU for weight initialization techniques).

# %%
# Create ANN Model

seed = 20
tf.keras.backend.clear_session()
np.random.seed(seed)
tf.random.set_seed(seed)

initializer = HeNormal(seed=seed)
loss_function = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.Adam()

model_relu = Sequential([
    Input(shape=(2,), name='input-layer'),
    Dense(5, activation='relu', kernel_initializer=initializer, name='hidden-layer-1'),
    Dense(5, activation='relu', kernel_initializer=initializer, name='hidden-layer-2'),
    Dense(5, activation='relu', kernel_initializer=initializer, name='hidden-layer-3'),
    Dense(1, activation="sigmoid", kernel_initializer=initializer, name='output-layer')
])

# Compile
model_relu.compile(loss=loss_function,
              optimizer=optimizer,
              metrics=['accuracy'])
model_relu.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden-layer-1 (Dense)      (None, 5)                 15
#
#  hidden-layer-2 (Dense)      (None, 5)                 30
#
#  hidden-layer-3 (Dense)      (None, 5)                 30
#
#  output-layer (Dense)        (None, 1)                 6
#
# =================================================================
# Total params: 81 (324.00 Byte)
# Trainable params: 81 (324.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the ANN Model

model_relu.fit(X_train, y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 1s 2ms/step - loss: 0.8050 - accuracy: 0.4765
# Epoch 2/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.7537 - accuracy: 0.4706
# Epoch 3/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.7206 - accuracy: 0.4718
# Epoch 4/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6989 - accuracy: 0.4718
# Epoch 5/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6819 - accuracy: 0.4635
# Epoch 6/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6673 - accuracy: 0.4718
# Epoch 7/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6541 - accuracy: 0.5329
# Epoch 8/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6416 - accuracy: 0.5824
# Epoch 9/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6292 - accuracy: 0.6000
# Epoch 10/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6168 - accuracy: 0.6106
# Epoch 11/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6040 - accuracy: 0.6353
# Epoch 12/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5911 - accuracy: 0.6565
# Epoch 13/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5775 - accuracy: 0.6753
# Epoch 14/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5643 - accuracy: 0.7129
# Epoch 15/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5513 - accuracy: 0.7271
# Epoch 16/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5378 - accuracy: 0.7459
# Epoch 17/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5253 - accuracy: 0.7612
# Epoch 18/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5131 - accuracy: 0.7847
# Epoch 19/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5009 - accuracy: 0.7882
# Epoch 20/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4885 - accuracy: 0.8059
# Epoch 21/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4763 - accuracy: 0.8188
# Epoch 22/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4640 - accuracy: 0.8200
# Epoch 23/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4514 - accuracy: 0.8294
# Epoch 24/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4389 - accuracy: 0.8412
# Epoch 25/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4267 - accuracy: 0.8529
# Epoch 26/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4147 - accuracy: 0.8612
# Epoch 27/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4027 - accuracy: 0.8671
# Epoch 28/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3914 - accuracy: 0.8718
# Epoch 29/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3797 - accuracy: 0.8765
# Epoch 30/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3682 - accuracy: 0.8776
# Epoch 31/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3565 - accuracy: 0.8859
# Epoch 32/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3436 - accuracy: 0.8871
# Epoch 33/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3320 - accuracy: 0.8929
# Epoch 34/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3196 - accuracy: 0.8988
# Epoch 35/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3041 - accuracy: 0.9082
# Epoch 36/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2829 - accuracy: 0.9235
# Epoch 37/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2582 - accuracy: 0.9353
# Epoch 38/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2349 - accuracy: 0.9412
# Epoch 39/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2161 - accuracy: 0.9588
# Epoch 40/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.2006 - accuracy: 0.9612
# Epoch 41/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1873 - accuracy: 0.9635
# Epoch 42/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1764 - accuracy: 0.9612
# Epoch 43/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1655 - accuracy: 0.9659
# Epoch 44/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1564 - accuracy: 0.9647
# Epoch 45/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1466 - accuracy: 0.9729
# Epoch 46/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1387 - accuracy: 0.9729
# Epoch 47/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1304 - accuracy: 0.9718
# Epoch 48/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1236 - accuracy: 0.9729
# Epoch 49/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1171 - accuracy: 0.9741
# Epoch 50/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1118 - accuracy: 0.9753
# Epoch 51/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1061 - accuracy: 0.9765
# Epoch 52/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1006 - accuracy: 0.9765
# Epoch 53/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0964 - accuracy: 0.9765
# Epoch 54/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0919 - accuracy: 0.9776
# Epoch 55/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0880 - accuracy: 0.9812
# Epoch 56/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0846 - accuracy: 0.9824
# Epoch 57/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0813 - accuracy: 0.9835
# Epoch 58/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0785 - accuracy: 0.9847
# Epoch 59/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0758 - accuracy: 0.9835
# Epoch 60/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0737 - accuracy: 0.9824
# Epoch 61/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0706 - accuracy: 0.9859
# Epoch 62/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0694 - accuracy: 0.9835
# Epoch 63/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0668 - accuracy: 0.9859
# Epoch 64/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0650 - accuracy: 0.9859
# Epoch 65/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0626 - accuracy: 0.9847
# Epoch 66/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0616 - accuracy: 0.9859
# Epoch 67/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0601 - accuracy: 0.9847
# Epoch 68/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0584 - accuracy: 0.9859
# Epoch 69/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0572 - accuracy: 0.9859
# Epoch 70/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0557 - accuracy: 0.9859
# Epoch 71/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0548 - accuracy: 0.9835
# Epoch 72/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0558 - accuracy: 0.9847
# Epoch 73/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0534 - accuracy: 0.9847
# Epoch 74/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0523 - accuracy: 0.9835
# Epoch 75/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0516 - accuracy: 0.9859
# Epoch 76/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0509 - accuracy: 0.9847
# Epoch 77/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0503 - accuracy: 0.9835
# Epoch 78/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0495 - accuracy: 0.9871
# Epoch 79/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0486 - accuracy: 0.9847
# Epoch 80/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0480 - accuracy: 0.9824
# Epoch 81/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0480 - accuracy: 0.9824
# Epoch 82/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0471 - accuracy: 0.9847
# Epoch 83/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0468 - accuracy: 0.9847
# Epoch 84/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 0.9824
# Epoch 85/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0462 - accuracy: 0.9871
# Epoch 86/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 0.9835
# Epoch 87/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0446 - accuracy: 0.9835
# Epoch 88/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0442 - accuracy: 0.9847
# Epoch 89/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0441 - accuracy: 0.9835
# Epoch 90/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0439 - accuracy: 0.9859
# Epoch 91/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0436 - accuracy: 0.9847
# Epoch 92/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0435 - accuracy: 0.9847
# Epoch 93/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0452 - accuracy: 0.9824
# Epoch 94/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0435 - accuracy: 0.9882
# Epoch 95/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 0.9835
# Epoch 96/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0419 - accuracy: 0.9847
# Epoch 97/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0417 - accuracy: 0.9859
# Epoch 98/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0419 - accuracy: 0.9847
# Epoch 99/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 0.9835
# Epoch 100/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0417 - accuracy: 0.9847

# %%
# Predict test-set

model_relu.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 1.0000
# [0.0175887830555439, 1.0]

# %% [markdown]
# After changing the activation function and weight initialization, it can be seen that the performance of the train and test has increased drastically, even approaching perfect conditions. Hooray.

# %% [markdown]
# # D. The Gradient

# %% [markdown]
# Let's look at the gradient differences between models that use the Sigmoid activation function with ReLU. Let's prove whether it is true that the Sigmoid activation function leads to a vanish gradient or not.

# %%
# Create a Function to Store Weights from Each Epoch

def train_model(X, y, model, loss_function, optimizer, n_epochs=100, batch_size=32):
    "Run training loop manually"
    train_dataset = tf.data.Dataset.from_tensor_slices((X, y))
    train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

    gradhistory = []
    losshistory = []
    def recordweight():
        data = {}
        for g,w in zip(grads, model.trainable_weights):
            if '/kernel:' not in w.name:
                continue # skip bias
            name = w.name.split("/")[0]
            data[name] = g.numpy()
        gradhistory.append(data)
        losshistory.append(loss_value.numpy())
    for epoch in range(n_epochs):
        for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
            with tf.GradientTape() as tape:
                y_pred = model(x_batch_train, training=True)
                loss_value = loss_function(y_batch_train, y_pred)

            grads = tape.gradient(loss_value, model.trainable_weights)
            optimizer.apply_gradients(zip(grads, model.trainable_weights))

            if step == 0:
                recordweight()

    recordweight()
    return gradhistory, losshistory

# %%
# Create a Function to Plot the Gradients of Each Epoch

def plot_gradient(gradhistory, losshistory):
    "Plot gradient mean and sd across epochs"
    fig, ax = plt.subplots(1, 3, sharex=True, constrained_layout=True, figsize=(15, 4))
    ax[0].set_title("Mean gradient")
    for key in gradhistory[0]:
        ax[0].plot(range(len(gradhistory)), [w[key].mean() for w in gradhistory], label=key)
    ax[0].legend()
    ax[1].set_title("S.D.")
    for key in gradhistory[0]:
        ax[1].semilogy(range(len(gradhistory)), [w[key].std() for w in gradhistory], label=key)
    ax[1].legend()
    ax[2].set_title("Loss")
    ax[2].plot(range(len(losshistory)), losshistory)
    plt.show()

# %%
# Check the Gradients on Sigmoid Model and ReLU Model

# %%time
loss_function = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.Adam()
gradhistory_sigmoid, losshistory_sigmoid = train_model(X_train, y_train, model_sigmoid, loss_function, optimizer, n_epochs=100, batch_size=32)

loss_function = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.Adam()
gradhistory_relu, losshistory_relu = train_model(X_train, y_train, model_relu, loss_function, optimizer, n_epochs=100, batch_size=32)

print('-- Sigmoid Model -- ')
plot_gradient(gradhistory_sigmoid, losshistory_sigmoid)
print('')

print('-- ReLU Model -- ')
plot_gradient(gradhistory_relu, losshistory_relu)
print('')
# Out:
# UsageError: Line magic function `%%time` not found.

# %% [markdown]
# **INSIGHTS :**
#
# 1. Sigmoid model :
#    * From the `Mean gradient` plot, it can be seen that only the gradients from the output layer has a fluctuating gradient.
#    * While the gradient of the other layers is around `0`.
#    * This causes the the loss value decreases slowly and even looks stagnant. This phenomenon is called vanishing gradient.
#
# 2. ReLU model :
#    * The gradient that comes from the ReLU model varies in each layer and tends to go up and down so it doesn't stagnate at `0`.
#    * This causes the loss values to change, allowing the model to reach its optimal point.
