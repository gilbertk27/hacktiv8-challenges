# %% [markdown]
# # Week 3: Day 5 AM // Web Scraping

# %% [markdown]
# ## Tools Preparation
# Scrapping is basically one of the way to retrieve the data and this process is very important to know as a data scientist since sometimes we cannot get data easily as we querying the data from the database or download Kaggle. We're going to scrape Gramedia.com in this lesson using Beautifulsoup. Before we're going further, please install beautifulsoup.
#
# To install beautifulsoup, you may run one of the following commands on Anaconda Prompt (Windows) or Terminal (Linux/Mac/VSCode):
#
# ```
# pip install bs4
# ```
#
# and also you need to install requests to acces a web address by running:
#
# ```
# pip install requests
# ```
#
# ```
# pip install selenium
# ```

# %%
! pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\programdata\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.0.1)

# %%
! pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\gilbert kh\appdata\roaming\python\python38\site-packages (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests) (1.25.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gilbert kh\appdata\roaming\python\python38\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2020.6.20)

# %%
! pip install --user selenium
# Out:
# Collecting selenium
#   Using cached selenium-4.15.2-py3-none-any.whl (10.2 MB)
# Collecting urllib3[socks]<3,>=1.26
#   Using cached urllib3-2.1.0-py3-none-any.whl (104 kB)
# Requirement already satisfied: trio-websocket~=0.9 in c:\programdata\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: trio~=0.17 in c:\programdata\anaconda3\lib\site-packages (from selenium) (0.23.1)
# Collecting certifi>=2021.10.8
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# conda 4.10.3 requires ruamel_yaml_conda>=0.11.14, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
#   Using cached certifi-2023.11.17-py3-none-any.whl (162 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6; extra == "socks" in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: exceptiongroup; python_version < "3.11" in c:\programdata\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in c:\programdata\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.2.2)
# Requirement already satisfied: cffi>=1.14; os_name == "nt" and implementation_name != "pypy" in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.3)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: attrs>=20.1.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (20.3.0)
# Requirement already satisfied: outcome in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\programdata\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14; os_name == "nt" and implementation_name != "pypy"->trio~=0.17->selenium) (2.20)
# Installing collected packages: urllib3, certifi, selenium
# Successfully installed certifi-2023.11.17 selenium-4.15.2 urllib3-2.1.0

# %% [markdown]
# ### Selenium WebDriver
#
# Selenium WebDriver is a powerful tool for automating browser interactions and testing web applications. It provides a programming interface to control browser behavior and perform actions such as clicking buttons, filling forms, and navigating through web pages.
#
# To get started with Selenium WebDriver for different browsers, you'll need to ensure that you have the appropriate browser drivers installed and set up correctly. Each browser requires its specific driver to communicate with Selenium.
#
# 1. Google Chrome:
#    - You need to download the ChromeDriver executable and place it in a location that is in your system's PATH.
#    - Official ChromeDriver download page: https://sites.google.com/chromium.org/driver/
#
# 2. Safari:
#    - SafariDriver is automatically installed with Safari on macOS.
#    - To enable it, go to Safari preferences, then to the 'Advanced' tab, and check the "Show Develop menu in menu bar" option.
#    - After that, in the Develop menu, go to "Allow Remote Automation" to enable SafariDriver.
#
# 3. Firefox:
#    - You need to download the geckodriver executable and place it in a location that is in your system's PATH.
#    - Official geckodriver download page: https://github.com/mozilla/geckodriver/releases
#
# 4. Microsoft Edge:
#    - For Microsoft Edge (Chromium-based version), you need to download the Microsoft Edge Driver (also known as MSEdgeDriver) and place it in a location that is in your system's PATH.
#    - Official MSEdgeDriver download page: https://developer.microsoft.com/en-us/microsoft-edge/tools/webdriver/
#
# Once you have set up the appropriate drivers, you can use Selenium WebDriver in your preferred programming language (Python, Java, C#, etc.) to automate interactions with the browsers.
#
# Here's the codes of how to define Selenium WebDriver with Python for Chrome, Safari, Firefox, and Microsoft Edge:
#
# ```python
# from selenium import webdriver
#
#
# # Create a new instance of the Chrome browser
# driver = webdriver.Chrome("/path/to/chromedriver")
#
# # Create a new instance of the Safari browser
# driver = webdriver.Safari()
#
# # Create a new instance of the Firefox browser
# driver = webdriver.Firefox("/path/to/geckodriver")
#
# # Create a new instance of the Microsoft Edge browser
# driver = webdriver.Edge("/path/to/msedgedriver")
# ```
#
# Similarly, you can use WebDriver with other browsers by using the appropriate driver for each browser and modifying the setup accordingly.
#
# Always ensure you are using the latest versions of Selenium WebDriver and browser drivers to avoid compatibility issues. You can check the Selenium official website (https://www.selenium.dev/) and the respective browser driver download pages for updates and documentation.

# %% [markdown]
# ## Basic Web Component
#
# The website that you are scraping in this lesson contains several components. Those are:
# - HTML — the main content of the page.
# - CSS — used to add styling to make the page look nicer.
# - JS — Javascript files add interactivity to web pages.
# - Images — image formats, such as JPG and PNG, allow web pages to show pictures.
#
# There’s a lot that happens behind the scenes to render a page nicely, but we don’t need to worry about most of it when we’re web scraping. When we perform web scraping, we’re interested in the main content of the web page, so we look primarily at the HTML. Hence, you need to know some HTML structure to ease your scraping works. But don't worry, you don't need to dive in deeply into it.
#
# ### HTML Structure
#
# HyperText Markup Language (HTML) is the language that web pages are created in. HTML isn’t a programming language, like Python, though. It’s a markup language that tells a browser how to display content.
#
# HTML has many functions that are similar to what you might find in a word processor like Microsoft Word — it can make text bold, create paragraphs, and so on.
#
# Below an example of HTML structure:
#
# ```html
# <HTML>
#     <HEAD>
#         <TITLE>My cool title</TITLE>
#     </HEAD>
#     <BODY>
#         <H1>This is a Header</H1>
#         <ul id="list" class="coolList">
#             <li>item 1</li>
#             <li>item 2</li>
#             <li>item 3</li>
#         </ul>
#     </BODY>
# </HTML>
# ```
#
# - The red items are called as tag or element. Usually, tag follows "<".
# - HTML, HEAD, and BODY are the main elements and the rests are the content. For your attention, we will focus on the contents.
# - The orange items are attribut that give information about the tag.
# - The blue texts are the attribute value.

# %% [markdown]
# ## Accessing the Web
#
# Now, we will access https://www.gramedia.com/categories/buku for this lesson. Before we go further, we need to understand how to access the url in Python. To do it, we use requests library.

# %%
import requests
page = requests.get("https://www.gramedia.com/categories/buku")
page
# Out:
# <Response [200]>

# %% [markdown]
# If you see the output is <Response [200]>, then you are success to access the url. "200" refers to HTTP status codes. You can read https://id.wikipedia.org/wiki/Daftar_kode_status_HTTP for further explaination.
#
# Now, you can check the HTML content of the page in Python. However, you can also check it on your browser by right click and choose Inspect element to ease your understanding od the web structure.

# %% [markdown]
# Above is the HTML structure that Python successfully access. We need to parsing the structure using Beautifulsoup to make it clear and accessible to scrape.

# %% [markdown]
# https://oak-tree.tech/blog/python-web-scraping-selenium

# %% [markdown]
# Pertama, kita akan menggunakan Selenium untuk mengotomatiskan klik tombol

# %%
# !pip install -q selenium
# Out:
# WARNING: You are using pip version 20.2.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\dell\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# Salah satu keunggulan dari BeautifulSoup adalah bahwa ia dibangun di atas parsing library HTML

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
driver = webdriver.Chrome()
# driver= webdriver.Edge('blabla.exe')

url="https://www.gramedia.com/categories/buku"
driver.get(url)
html = driver.page_source

soup = BeautifulSoup(html, "html.parser") #Menentukan parser HTML yang ingin kita gunakan.
print(soup.prettify()[:700]) # memberikan representasi visual dari pohon parse yang dibuat dari konten HTML mentah.
# Out:
# <html class="" lang="id">
#  <head>
#   <base href="/"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="#281e5a" name="theme-color"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/assets/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="manifest.json" rel="manifest"/>
#   <link href="/assets/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="z91Vp6ZYo9UoX5D4ur6i4Lrl0l1j3DDoCH08fD3n53g" name="google-site-verification"/>
#   <meta content="810657685650228" property="fb:app_id"/>
#   <style>
#    .async-hide {
#         opacity: 0 !important
#     }
#   </style>
#   <script async="" src="https://app.

# %% [markdown]
# ### Apa itu Parse?
#
# Parse HTML merupakan suatu cara yang digunakan untuk mengurai atau membaca HTML untuk mengekstrak informasi tertentu dari tag dan elemen HTML. Parse jika diterjemahkan dalam Bahasa Indonesia berarti menguraikan.

# %% [markdown]
# <img src="https://i.ibb.co/vsz2M33/message-Image-1636690176458.jpg"></img>

# %% [markdown]
# Let that we want to retrieve the books' title, so let's check the title position on the HTML out using Inspect element!
#
# We know that based on the Inspect element, the books' title lie on this code:
#
# ```html
# <div _ngcontent-web-gramedia-c53="" class="list-title">Creepy Case Club 4: Kasus Pohon Pemanggil</div>
# ```
#
# "Creepy Case Club 4: Kasus Pohon Pemanggil" located at **div** tag with attribute **class** and the value of "*list-title*". So we will use the information to inform the soup where the titles exist.
#
# So we need to find all div elements that contain attribute class and value "list-title".
#
# To do that, we use ```soup.find_all("<element>",{"<attribute>":"<attribute value>"})```

# %% [markdown]
# `<span _ngcontent-web-gramedia-c26="" class="list-author"> Apt Tatiana Siska Wardani S.Farm.,M.Farm </span>`

# %% [markdown]
# find_all untuk semua tag elements

# %%
soup.find_all('span', {"class":"list-author"})
# Out:
# [<span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Apt Tatiana Siska Wardani S.Farm.,M.Farm </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Pdt. Dr. Nancy Souisa, M.Si., Tirsa Budiarti, M.Si., Caren V.Y. Gultom, S.Si.Teol., M.M., Rinny Kaligis, S.Si.Teol., M.Si., Pdt. Dr. Daniel Nuhamara, M.Th. </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Widi Nugrahaningsih, Sh.,Mh, Rayhan Gunaningrat, Se.,Mm, Esti Dwi Rahmawati, Se., Mm, Dan Aris Prio Agus </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Intan Oktaviani S.Kom.,M.Kom, Dan Rizki Pujiyanto S.E., M.M </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Kak Freddie &amp; Kak Andiko </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Erna Chotidjah Suhatmi, SE.,M.Ak </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Esti Dwi Rahmawati SE.,MM. </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Ratih Maharani </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Munawaroh None </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Arinaga Family </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Tikah Kumala </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Qoriroh - </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Andi Luqmanul Qosim, Lc., M.Pd.I. </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Arisatya Yogaswara </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Ipnu R, Noegroho </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Stella Christiani </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Muhammad Syafii Masykur </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Danrivanto Budhijanto, S.H., Ll.M. In It Law, Fcbarb., Fiiarb. </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Nur Rohman, S.Pd., M.Pd., None </span>,
#  <span _ngcontent-web-gramedia-c26="" class="list-author ng-star-inserted"> Firman Rni, M.Pd., Kons., Cht None </span>]

# %% [markdown]
# We see that the soup found all div elements that contain attribute class and value "list-title" but we need the title text only. To extract it, just add .get_text() method to each list element.

# %%
for div_tag in soup.find_all('div',{"class":"list-title"}):  #sebagai content spesifik yang akan kita ambil.
    print(div_tag.get_text())
# Out:
# Manajemen Farmasi & Alat Kesehatan
# Pendidikan Agama Kristen dan Budi Pekerti SMP Kelas 9
# Pengantar Manajemen Pemerintahan
# Ekonomi Manajemen : Ekonomi Manajerial
# Komik Riwayat Peradaban Arab Sebelum Islam
# Manajemen Keuangan
# Manajemen Pemasaran
# Buku Mewarnai Kisah Kasih Tuhan Yesus
# Belajar Mudah Hiragana dan Katakana
# Tarian Ayam
# Biarlah Hati Baperan Selama Masih Berperan
# Bisnis Sukses Cara Nabi
# Buku Tuntunan Super Lengkap Shalat Wajib & Sunnah
# Pemimpin Vs Bos
# Kitab Hafalan Cepat Juz 29 : Dilengkapi Dengan Transliterasi
# You May Think I`m Quite, But I Have Universe in My Mind
# Panduan Praktis Mudah dan Lengkap Belajar Shalat
# Hukum Pelindungan Data Pribadi Di Indonesia: Cyberlaw & Cybersecurity
# Profesi Keguruan
# Teknik Self Counseling: Mengubah Stres Menjadi Bahagia Teori & Praktik

# %% [markdown]
# It is easy, isn't it?
#
# Next, we will do more. Our task is to get information about Title, Author, Price, Link to the book's page, and link refers to image.
#
# Based on the Inspect element, we know that those information locate on:
# - Title: ```<div _ngcontent-web-gramedia-c53="" class="list-title">Creepy Case Club 4: Kasus Pohon Pemanggil</div>```
# - Author: ```<p class="div-author"><span _ngcontent-web-gramedia-c53="" class="list-author ng-star-inserted"> Arvidan None </span>```
# - Price: ```<p _ngcontent-web-gramedia-c53="" class="formats-price">Rp 79.000</p>```
# - Link: ```<div class="ng-star-inserted"><a _ngcontent-web-gramedia-c53="" href="/products/think-and-grow-rich-cara-para-jutawan-dan-miliarder-meraih-kekayaan">```
# - Image: ```<img _ngcontent-web-gramedia-c26="" class="product-list-img ng-star-inserted ng-lazyloaded" src="https://cdn.gramedia.com/uploads/items/9786230405990_Think_and_Grow_Rich__w149_hauto.jpeg" alt="Think And Grow Rich : Cara Para Jutawan Dan Miliarder Meraih Kekayaan">```
#
# Let's we wrap up the code and then input the data into Pandas DataFrame.

# %% [markdown]
# **References**
#
# - [Dokumentasi Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# - [Latihan dasar webscraping](https://github.com/omarmisaac/Web-Scraping/blob/main/Web_Scraping.ipynb)

# %%
import pandas as pd

#Buat dataframe Data
data = pd.DataFrame()

#Data Title
data['Title'] = [ title.get_text() for title in soup.find_all( 'div', {"class":"list-title"})]

#Data Author
data['Author'] = [ author.get_text() for author in soup.find_all( 'p', {"class":"div-author"})]

#Data Price
data['Price'] = [ price.get_text() for price in soup.find_all( 'p', {"class":"formats-price"})]

#Data Image
data['Image'] = [ img['src'] for img in soup.find_all( 'img',{"class":"product-list-img"})]

#Data Links
links = []

#cara ke 1
# for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
#     try:
#         links.append("https://www.gramedia.com"+tag.find_all('a',{"_ngcontent-web-gramedia-c26":""})[0]['href'])
#     except:
#         pass

#cara ke 2
for tag in soup.find_all('a',attrs={"_ngcontent-web-gramedia-c26": True,"href":True}):
    print(tag.get('href'))
    links.append("https://www.gramedia.com"+tag.get('href'))
data['Link'] = links

data
# Out:
#                                                 Title  \
# 0   Pemberdayaan Majelis Taklim Dalam Pencegahan K...
# 1   Post-Qualitative Social Research Methods Edisi...
# 2              Komik Next G Vol. 495: Pelit Jadi Baik
# 3                             City Lite : Requisition
# 4                                     The Kite Runner
# 5               Analisi Kesalahan Berbahasa Indonesia
# 6                                      Cerita Si Ayam
# 7                                    Cerita Si Kucing
# 8                                Memoir of Vanitas 09
# 9                                 La La Love Choir 03
# 10                The Misfit of Demon King Academy 01
# 11                 Kubo Won`t Let Me Be Invinsible 01
# 12  Opredo Kartu Seru Hafiz Hafizah - Animals, Fru...
# 13  Opredo Kartu Seru Hafiz Hafizah - Angka & Huru...
# 14  Sejarah Revolusi Industri : Dari Asal Muasal, ...
# 15  Seni Bergaya Hidup Minimalis: Atur Kembali Hid...
# 16           Die-Cut Shaped Vehicles: Speedy Race Car
# 17  DAHSYATNYA MARKETING ISLAMI; Memasarkan Bukan ...
# 18                  Bahagia Beragama Bersama Gus Baha
# 19                                 Discovering Myself
#
#                                                Author       Price  \
# 0                                     Prima Harrison    Rp 66.300
# 1    Prof. Dr. Burhan Bungin, M.Si., Ph.D., Ciqar....  Rp 140.250
# 2                                   Safira Dwi Putri    Rp 33.150
# 3                                    AYUNITA KURAISY    Rp 88.000
# 4                                    Khaled Hosseini    Rp 89.250
# 5                          DR. JUNAIYAH H. MATANGGUI    Rp 42.500
# 6                                               Orin    Rp 29.750
# 7                                          ORIN None    Rp 29.750
# 8                                      Jun Mochizuki    Rp 25.600
# 9                                         Yakko Kaga    Rp 32.000
# 10                                  Shu, Kaya Haruka    Rp 36.000
# 11                                     Nene Yukimori    Rp 40.000
# 12                            PT Hidayah Insan Mulia    Rp 79.200
# 13                            PT Hidayah Insan Mulia    Rp 79.200
# 14                        Anisa Septianingrum, M.pd.    Rp 42.500
# 15                                       Asti Musman    Rp 42.500
# 16                                                      Rp 33.150
# 17                                   Erik Arya Tandi    Rp 60.000
# 18                                      Khoirul Anam    Rp 68.000
# 19                                       OPSY Clinic   Rp 128.000
#
#                                                 Image  \
# 0   https://cdn.gramedia.com/uploads/items/Cover_P...
# 1   https://cdn.gramedia.com/uploads/items/Post-Qu...
# 2   https://cdn.gramedia.com/uploads/items/img2022...
# 3   https://cdn.gramedia.com/uploads/items/9786230...
# 4   https://cdn.gramedia.com/uploads/items/The_Kit...
# 5   https://cdn.gramedia.com/uploads/items/img2022...
# 6                  /assets/default-images/product.png
# 7                  /assets/default-images/product.png
# 8                  /assets/default-images/product.png
# 9                  /assets/default-images/product.png
# 10                 /assets/default-images/product.png
# 11                 /assets/default-images/product.png
# 12                 /assets/default-images/product.png
# 13                 /assets/default-images/product.png
# 14                 /assets/default-images/product.png
# 15                 /assets/default-images/product.png
# 16                 /assets/default-images/product.png
# 17                 /assets/default-images/product.png
# 18                 /assets/default-images/product.png
# 19                 /assets/default-images/product.png
#
#                                                  Link
# 0   https://www.gramedia.com/products/pemberdayaan...
# 1   https://www.gramedia.com/products/post-qualita...
# 2   https://www.gramedia.com/products/komik-next-g...
# 3   https://www.gramedia.com/products/city-lite-re...
# 4   https://www.gramedia.com/products/the-kite-run...
# 5   https://www.gramedia.com/products/analisi-kesa...
# 6    https://www.gramedia.com/products/cerita-si-ayam
# 7   https://www.gramedia.com/products/cerita-si-ku...
# 8   https://www.gramedia.com/products/memoir-of-va...
# 9   https://www.gramedia.com/products/la-la-love-c...
# 10  https://www.gramedia.com/products/the-misfit-o...
# 11  https://www.gramedia.com/products/kubo-wont-le...
# 12  https://www.gramedia.com/products/opredo-kartu...
# 13  https://www.gramedia.com/products/opredo-kartu...
# 14  https://www.gramedia.com/products/sejarah-revo...
# 15  https://www.gramedia.com/products/seni-bergaya...
# 16  https://www.gramedia.com/products/die-cut-shap...
# 17  https://www.gramedia.com/products/dahsyatnya-m...
# 18  https://www.gramedia.com/products/bahagia-bera...
# 19  https://www.gramedia.com/products/discovering-...

# %%
#save variable data to csv
data.to_csv('data.csv', index=False)

# %% [markdown]
# ## Multipage

# %% [markdown]
# Currently, we are working on a page. However, the rest of the web consist of more pages like below:
#
#
# <img src="https://i.ibb.co/CQ6JQLv/message-Image-1636716930335.jpg"></img>
#
# If we look at the next page such as page 2, we can see that the url change to https://www.gramedia.com/categories/buku?page=2 and page 3: https://www.gramedia.com/categories/buku?page=3. Then we know each page has a numbering format on url so we can access many pages one time automatically using loop. We exclude the image since image loader is very depended on your connection. Let's check the code below.

# %% [markdown]
# **References** :
#
# - [Web Scraping IMDB](https://github.com/gshreyans/Web-Scraping-Multiple-Pages-/blob/master/IMDB%20Multiple%20Pages%20.ipynb)

# %%
title = []
author = []
price = []
image = []
Links = []

for i in range(1,3):
    url="https://www.gramedia.com/categories/buku?page={}".format(i)
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    title += [ title.get_text() for title in soup.find_all( 'div', {"class":"list-title"} ) ]
    author += [ author.get_text() for author in soup.find_all( 'p', {"class":"div-author"} ) ]
    price += [ price.get_text() for price in soup.find_all( 'p', {"class":"formats-price"} ) ]
    image += [ img['src'] for img in soup.find_all( 'img',{"class":"product-list-img"} ) ]

    links = []
    for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
        try:
            links.append("https://www.gramedia.com"+tag.find_all('a',{"_ngcontent-web-gramedia-c26":""})[0]['href'])
        except:
            pass
    Links += links

data_multipage = pd.DataFrame()
data_multipage['Title'] = title
data_multipage['Author'] = author
data_multipage['Price'] = price
data_multipage['Image'] = image
data_multipage['Link'] = Links

data_multipage
# Out:
#                                                 Title  \
# 0                  Manajemen Farmasi & Alat Kesehatan
# 1   Pendidikan Agama Kristen dan Budi Pekerti SMP ...
# 2                    Pengantar Manajemen Pemerintahan
# 3              Ekonomi Manajemen : Ekonomi Manajerial
# 4          Komik Riwayat Peradaban Arab Sebelum Islam
# 5                                  Manajemen Keuangan
# 6                                 Manajemen Pemasaran
# 7               Buku Mewarnai Kisah Kasih Tuhan Yesus
# 8                 Belajar Mudah Hiragana dan Katakana
# 9                                         Tarian Ayam
# 10         Biarlah Hati Baperan Selama Masih Berperan
# 11                            Bisnis Sukses Cara Nabi
# 12  Buku Tuntunan Super Lengkap Shalat Wajib & Sunnah
# 13                                    Pemimpin Vs Bos
# 14  Kitab Hafalan Cepat Juz 29 : Dilengkapi Dengan...
# 15  You May Think I`m Quite, But I Have Universe i...
# 16   Panduan Praktis Mudah dan Lengkap Belajar Shalat
# 17  Hukum Pelindungan Data Pribadi Di Indonesia: C...
# 18                                   Profesi Keguruan
# 19  Teknik Self Counseling: Mengubah Stres Menjadi...
# 20  Anak Pintar Membaca Dan Menulis Huruf Angka Si...
# 21  Level Comic: Gokushufudo - The Way of House Hu...
# 22                    Level Comic: Tokyo Revengers 08
# 23                        Chion And The Cat Temple 08
# 24                              Fly Me to the Moon 10
# 25                                    Black Butler 32
# 26                  DEMON SLAYER: Kimetsu no Yaiba 13
# 27                                      One Piece 102
# 28                                  Jujutsu Kaisen 09
# 29         Ayo, Gambar dan Warnai: Putri dan Unicorn!
# 30                                       Blue Lock 05
# 31         Aktivitas Balita Cerdas: Jelajah Antariksa
# 32                                    Sabar Itu Keren
# 33                                     My Boring Life
# 34                   Aku Sedang Benar-benar Berproses
# 35                                   Siapa itu Allah?
# 36                                   Apa itu Ramadan?
# 37                               Jadilah Diri Sendiri
# 38                                 Peta Rahasia Nehan
# 39    Frozen II: Cerita Emily - Edisi Mewarnai Cerita
#
#                                                Author      Price  \
# 0           Apt Tatiana Siska Wardani S.Farm.,M.Farm   Rp 40.000
# 1    Pdt. Dr. Nancy Souisa, M.Si., Tirsa Budiarti,...  Rp 78.000
# 2    Widi Nugrahaningsih, Sh.,Mh, Rayhan Gunaningr...  Rp 43.000
# 3    Intan Oktaviani S.Kom.,M.Kom, Dan Rizki Pujiy...  Rp 40.000
# 4                           Kak Freddie & Kak Andiko   Rp 88.000
# 5                   Erna Chotidjah Suhatmi, SE.,M.Ak   Rp 40.000
# 6                         Esti Dwi Rahmawati SE.,MM.   Rp 40.000
# 7                                     Ratih Maharani   Rp 44.000
# 8                                     Munawaroh None   Rp 59.000
# 9                                     Arinaga Family   Rp 50.000
# 10                                      Tikah Kumala   Rp 59.000
# 11                                         Qoriroh -   Rp 60.000
# 12                 Andi Luqmanul Qosim, Lc., M.Pd.I.   Rp 60.000
# 13                                Arisatya Yogaswara   Rp 54.000
# 14                                  Ipnu R, Noegroho   Rp 59.500
# 15                                 Stella Christiani   Rp 55.000
# 16                           Muhammad Syafii Masykur   Rp 55.000
# 17   Danrivanto Budhijanto, S.H., Ll.M. In It Law,...  Rp 57.000
# 18                    Nur Rohman, S.Pd., M.Pd., None   Rp 44.000
# 19                Firman Rni, M.Pd., Kons., Cht None   Rp 52.000
# 20                                  Linggar Swastika   Rp 45.000
# 21                                      Kousuke Oono   Rp 40.000
# 22                                         Ken Wakui   Rp 40.000
# 23                                      Ojiro Makoto   Rp 32.000
# 24                                      Hata Kenjiro   Rp 32.000
# 25                                       Yana Toboso   Rp 32.000
# 26                                  Koyoharu Gotouge   Rp 40.000
# 27                                      Eiichiro Oda   Rp 45.000
# 28                                      Gege Akutami   Rp 40.000
# 29                                         Liliawati   Rp 48.000
# 30                                Muneyuki Kaneshiro   Rp 45.000
# 31                                  Martina Ekaristi   Rp 48.000
# 32                Indrayani Mallo dan Nuha Maulida F   Rp 45.000
# 33                                        Rifta None   Rp 59.000
# 34                                   Endra El-Faeyza   Rp 49.000
# 35                                    Bachar Karroum   Rp 49.000
# 36                                    Bachar Karroum   Rp 49.000
# 37   Nabawi Putri Alifa, `Abdurrohman Faiz Al-Kher...  Rp 52.000
# 38                                      Maya Lestari   Rp 49.000
# 39   The Walt Disney Company (South Asia) - Singap...  Rp 35.000
#
#                                                 Image  \
# 0   https://cdn.gramedia.com/uploads/picture_meta/...
# 1   https://cdn.gramedia.com/uploads/picture_meta/...
# 2   https://cdn.gramedia.com/uploads/picture_meta/...
# 3   https://cdn.gramedia.com/uploads/picture_meta/...
# 4   https://cdn.gramedia.com/uploads/picture_meta/...
# 5   https://cdn.gramedia.com/uploads/picture_meta/...
# 6                  /assets/default-images/product.png
# 7                  /assets/default-images/product.png
# 8                  /assets/default-images/product.png
# 9                  /assets/default-images/product.png
# 10                 /assets/default-images/product.png
# 11                 /assets/default-images/product.png
# 12                 /assets/default-images/product.png
# 13                 /assets/default-images/product.png
# 14                 /assets/default-images/product.png
# 15                 /assets/default-images/product.png
# 16                 /assets/default-images/product.png
# 17                 /assets/default-images/product.png
# 18                 /assets/default-images/product.png
# 19                 /assets/default-images/product.png
# 20  https://cdn.gramedia.com/uploads/picture_meta/...
# 21  https://cdn.gramedia.com/uploads/picture_meta/...
# 22  https://cdn.gramedia.com/uploads/picture_meta/...
# 23  https://cdn.gramedia.com/uploads/picture_meta/...
# 24  https://cdn.gramedia.com/uploads/picture_meta/...
# 25  https://cdn.gramedia.com/uploads/picture_meta/...
# 26                 /assets/default-images/product.png
# 27                 /assets/default-images/product.png
# 28                 /assets/default-images/product.png
# 29                 /assets/default-images/product.png
# 30                 /assets/default-images/product.png
# 31                 /assets/default-images/product.png
# 32                 /assets/default-images/product.png
# 33                 /assets/default-images/product.png
# 34                 /assets/default-images/product.png
# 35                 /assets/default-images/product.png
# 36                 /assets/default-images/product.png
# 37                 /assets/default-images/product.png
# 38                 /assets/default-images/product.png
# 39                 /assets/default-images/product.png
#
#                                                  Link
# 0   https://www.gramedia.com/products/manajemen-fa...
# 1   https://www.gramedia.com/products/pendidikan-a...
# 2   https://www.gramedia.com/products/pengantar-ma...
# 3   https://www.gramedia.com/products/ekonomi-mana...
# 4   https://www.gramedia.com/products/komik-riwaya...
# 5   https://www.gramedia.com/products/manajemen-ke...
# 6   https://www.gramedia.com/products/manajemen-pe...
# 7   https://www.gramedia.com/products/buku-mewarna...
# 8   https://www.gramedia.com/products/belajar-muda...
# 9       https://www.gramedia.com/products/tarian-ayam
# 10  https://www.gramedia.com/products/biarlah-hati...
# 11  https://www.gramedia.com/products/bisnis-sukse...
# 12  https://www.gramedia.com/products/buku-tuntuna...
# 13  https://www.gramedia.com/products/pemimpin-vs-bos
# 14  https://www.gramedia.com/products/kitab-hafala...
# 15  https://www.gramedia.com/products/you-may-thin...
# 16  https://www.gramedia.com/products/panduan-prak...
# 17  https://www.gramedia.com/products/hukum-pelind...
# 18  https://www.gramedia.com/products/profesi-kegu...
# 19  https://www.gramedia.com/products/teknik-self-...
# 20  https://www.gramedia.com/products/anak-pintar-...
# 21  https://www.gramedia.com/products/level-comic-...
# 22  https://www.gramedia.com/products/level-comic-...
# 23  https://www.gramedia.com/products/chion-and-th...
# 24  https://www.gramedia.com/products/fly-me-to-th...
# 25  https://www.gramedia.com/products/black-butler-32
# 26  https://www.gramedia.com/products/demon-slayer...
# 27    https://www.gramedia.com/products/one-piece-102
# 28  https://www.gramedia.com/products/jujutsu-kais...
# 29  https://www.gramedia.com/products/ayo-gambar-d...
# 30     https://www.gramedia.com/products/blue-lock-05
# 31  https://www.gramedia.com/products/aktivitas-ba...
# 32  https://www.gramedia.com/products/sabar-itu-keren
# 33   https://www.gramedia.com/products/my-boring-life
# 34  https://www.gramedia.com/products/aku-sedang-b...
# 35  https://www.gramedia.com/products/siapa-itu-allah
# 36  https://www.gramedia.com/products/apa-itu-rama...
# 37  https://www.gramedia.com/products/jadilah-diri...
# 38  https://www.gramedia.com/products/peta-rahasia...
# 39  https://www.gramedia.com/products/frozen-ii-ce...
